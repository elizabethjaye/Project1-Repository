# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

#file to load
api_pulls = "Resources/api_pulls.csv"

pull_data = pd.read_csv(api_pulls)
pull_data.head()
# Out:
#                                          Formal_Name  \
# 0     Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 2  Estimate!!SCHOOL ENROLLMENT!!Population 3 year...
# 3  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
# 4  Estimate!!EDUCATIONAL ATTAINMENT!!Population 2...
#
#                                        Label_Name 2017_Variable 2016_Variable  \
# 0                                      Households    DP02_0001E    DP02_0001E
# 1                             Households (Family)    DP02_0002E    DP02_0002E
# 2                    Number of Higher Ed Enrolled    DP02_0057E    DP02_0057E
# 3  Education of Some College - No Degree Attained    DP02_0062E    DP02_0062E
# 4        Education of Associate's Degree Attained    DP02_0063E    DP02_0063E
#
#   2015_Variable 2014_Variable 2013_Variable
# 0    DP02_0001E    DP02_0001E    DP02_0001E
# 1    DP02_0002E    DP02_0002E    DP02_0002E
# ...

# %%
base_url = "https://api.census.gov/data/"
counter = 0
data_year = []
data_acronym = []


url = base_url + data_year[counter] + "/" + data_acronym[counter]
